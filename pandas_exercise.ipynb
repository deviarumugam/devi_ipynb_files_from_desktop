# %%
import pandas as pd
import numpy as np
draft=pd.read_csv('ex1.csv')

# %%
draft
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft1=pd.read_table('test.tsv')

# %%
draft1=pd.read_table('ex1.csv',sep='#')

# %%
draft1=pd.read_csv('test.tsv',sep='\t')

# %%
draft1
# Out:
#                                           0
# 0             test\t test\ttest\ttest\ttest
# 1        sudh\tsudh\tsudh\tsudh\tsudh\tsudh
# 2  kumar\tkumar\tkumar\tkumar\tkumar\tkumar

# %%
draft2=pd.read_csv('test.tsv',header=None)

# %%
draft2
# Out:
#                                           0
# 0             test\t test\ttest\ttest\ttest
# 1        sudh\tsudh\tsudh\tsudh\tsudh\tsudh
# 2  kumar\tkumar\tkumar\tkumar\tkumar\tkumar

# %%
draft2.tail(1)
# Out:
#                                           0
# 2  kumar\tkumar\tkumar\tkumar\tkumar\tkumar

# %%
draft2=pd.read_csv('test.tsv',names=['aaa','bbb','ccc'])

# %%
draft2
# Out:
#                                         aaa  bbb  ccc
# 0             test\t test\ttest\ttest\ttest  NaN  NaN
# 1        sudh\tsudh\tsudh\tsudh\tsudh\tsudh  NaN  NaN
# 2  kumar\tkumar\tkumar\tkumar\tkumar\tkumar  NaN  NaN

# %%
pd1=pd.read_csv('ex1.csv')

# %%
pd1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd1=pd.read_csv('ex1.csv',header=None)

# %%
pd1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
pd1.head()
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
pd1.tail(2)
# Out:
#    0   1   2   3      4
# 2  5   6   7   8  world
# 3  9  10  11  12    foo

# %%
pd1=pd.read_csv('csv_mindex.csv')

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
pd1=pd.read_csv('csv_mindex.csv',index_col=['key1','key2'])

# %%
pd1
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd1=pd.read_csv('csv_mindex.csv',sep=',')

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
pd1=pd.read_csv('csv_mindex.csv',na_values=["one"])

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  NaN    a       1       2
# 1  NaN    b       3       4
# 2  NaN    c       5       6
# 3  NaN    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
pd1=pd.read_excel('C:/Users/Sreenivasan/ipynb_files/examples/ex1.xlsx',sheet_name='Sheet1')

# %%
pd1
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
url="https://www.w3schools.com/howto/howto_css_table_zebra.asp"
u1=pd.read_html(url)

# %%
u1
# Out:
# [  First Name Last Name  Points
#  0       Jill     Smith      50
#  1        Eve   Jackson      94
#  2       Adam   Johnson      67]

# %%
pd1=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",sep='\t')

# %%
pd1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
pd1['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
type(pd1['Pclass'])
# Out:
# pandas.core.series.Series

# %%
pd1[['Pclass','Name']]
# Out:
#      Pclass                                               Name
# 0         3                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         3                           Allen, Mr. William Henry
# ..      ...                                                ...
# 151       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152       3                                   Meo, Mr. Alfonzo
# 153       3                    van Billiard, Mr. Austin Blyler
# 154       3                              Olsen, Mr. Ole Martin
# 155       1                        Williams, Mr. Charles Duane
#
# [156 rows x 2 columns]

# %%
pd1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd1=pd.read_csv('csv_mindex.csv')

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
pd1.head(5)
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10

# %%
pd1=pd.read_csv('csv_mindex.csv',nrows=5)

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10

# %%
chunk=pd.read_csv('csv_mindex.csv')
chunk
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
chunk=pd.read_csv('csv_mindex.csv',chunksize=100)
chunk

# %%
pd1=pd.read_csv('csv_mindex.csv',nrows=5)
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10

# %%
pd1.to_csv('out.csv')

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10

# %%
pd1.to_csv('out1.csv',sep='#')

# %%
pd1
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10

# %%
import sqlite3
db=sqlite3.connect("xyz")
db.execute("drop table if exists grade")
db.execute("create table grade(id int,name text,score int)")
db.execute("insert into grade(id, name, score) values(1,'xxx',100)")
db.execute("insert into grade(id, name, score) values(2,'xxx',100)")
db.execute("insert into grade(id, name, score) values(3,'xxx',100)")
db.execute("insert into grade(id, name, score) values(4,'xxx',100)")
db.execute("insert into grade(id, name, score) values(5,'xxx',100)")

# %%
db.commit()

# %%
res=db.execute("select * from grade order by id")
for row in res:
    print((row))
# Out:
# (1, 'xxx', 100)
# (2, 'xxx', 100)
# (3, 'xxx', 100)
# (4, 'xxx', 100)
# (5, 'xxx', 100)

# %%
res=db.execute("select * from grade where name='xxx'")
for row in res:
        print((row))
# Out:
# (1, 'xxx', 100)
# (2, 'xxx', 100)
# (3, 'xxx', 100)
# (4, 'xxx', 100)
# (5, 'xxx', 100)

# %%
res=db.execute("select * from grade where score>90")
for row in res:
        print((row))
# Out:
# (1, 'xxx', 100)
# (2, 'xxx', 100)
# (3, 'xxx', 100)
# (4, 'xxx', 100)
# (5, 'xxx', 100)
