# %%
import pandas as pd

# %%
xy=pd.read_csv('C:/Users/Sreenivasan/Downloads/CardioVascularDisease/cardio_train.csv',sep=";")
xy
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0        988  22469       1     155    69.0    130     80            2     2
# 1        989  14648       1     163    71.0    110     70            1     1
# 2        990  21901       1     165    70.0    120     80            1     1
# 3        991  14549       2     165    85.0    120     80            1     1
# 4        992  23393       1     155    62.0    120     80            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69296  99993  19240       2     168    76.0    120     80            1     1
# 69297  99995  22601       1     158   126.0    140     90            2     2
# 69298  99996  19066       2     183   105.0    180     90            3     1
# 69299  99998  22431       1     163    72.0    135     80            1     2
# 69300  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
xy.info
# Out:
# <bound method DataFrame.info of           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0        988  22469       1     155    69.0    130     80            2     2
# 1        989  14648       1     163    71.0    110     70            1     1
# 2        990  21901       1     165    70.0    120     80            1     1
# 3        991  14549       2     165    85.0    120     80            1     1
# 4        992  23393       1     155    62.0    120     80            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69296  99993  19240       2     168    76.0    120     80            1     1
# 69297  99995  22601       1     158   126.0    140     90            2     2
# 69298  99996  19066       2     183   105.0    180     90            3     1
# 69299  99998  22431       1     163    72.0    135     80            1     2
# 69300  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
xy.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
x1=xy[xy.columns[0:12]]#'id','age','gender','height','weight','ap_hi','ap_lo','cholesterol','gluc','smoke','alco','active']
#del x1['id']
#del x1['age']
x1.info
# Out:
# <bound method DataFrame.info of        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           1     155    69.0    130     80            2     2      0     0
# 1           1     163    71.0    110     70            1     1      0     0
# 2           1     165    70.0    120     80            1     1      0     0
# 3           2     165    85.0    120     80            1     1      1     1
# 4           1     155    62.0    120     80            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69296       2     168    76.0    120     80            1     1      1     0
# 69297       1     158   126.0    140     90            2     2      0     0
# 69298       2     183   105.0    180     90            3     1      0     1
# 69299       1     163    72.0    135     80            1     2      0     0
# 69300       1     170    72.0    120     80            2     1      0     0
#
#        active
# ...

# %%
x2=x1.values
x2
# Out:
# array([[  1., 155.,  69., ...,   0.,   0.,   1.],
#        [  1., 163.,  71., ...,   0.,   0.,   1.],
#        [  1., 165.,  70., ...,   0.,   0.,   1.],
#        ...,
#        [  2., 183., 105., ...,   0.,   1.,   0.],
#        [  1., 163.,  72., ...,   0.,   0.,   0.],
#        [  1., 170.,  72., ...,   0.,   0.,   1.]])

# %%
y1=xy[xy.columns[12]]
y2=y1.values
y2
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(5,5))
plt.plot(x1,y1)

# %%
ax = xy.plot(figsize=(15,8), title='Cardio Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ax = x1.plot(figsize=(15,8), title='Cardio Dataset')

# %%
x1.iloc[0:60].plot(kind='bar')

# %%
from sklearn import svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1,y1)
SVC()
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf.predict([[1,155,69,130,80,2,2,0,0,1]])
# Out:
# array([1], dtype=int64)
