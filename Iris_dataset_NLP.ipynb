# %%
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each datapoint with specific class.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4eae6dd02835> in <module>
# ----> 1 iris = sns.load_dataset('iris')
#       2 iris.head()
#
# NameError: name 'sns' is not defined

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
iris.plot.hist()

# %%
# !pip install plotly
# !pip install cufflinks
# !pip install foliu
# Out:
# Requirement already satisfied: plotly in c:\users\sreenivasan\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\sreenivasan\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\sreenivasan\anaconda3\lib\site-packages (from plotly) (1.14.0)
# Collecting cufflinks
#   Downloading https://files.pythonhosted.org/packages/1a/18/4d32edaaf31ba4af9745dac676c4a28c48d3fc539000c29e855bd8db3b86/cufflinks-0.17.3.tar.gz (81kB)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (1.18.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (0.25.1)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (4.6.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (1.14.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading https://files.pythonhosted.org/packages/9a/53/f696e4480b1d1de3b1523991dea71cf417c8b19fe70c704da164f3f90972/colorlover-0.3.0-py3-none-any.whl
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (41.4.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (7.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\sreenivasan\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: pygments in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.4.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.15.1)
# Requirement already satisfied: decorator in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.4.0)
# Requirement already satisfied: pickleshare in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.0.10)
# Requirement already satisfied: backcall in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.2)
# Requirement already satisfied: ipython-genutils in c:\users\sreenivasan\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: parso>=0.5.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->cufflinks) (0.5.1)
# Requirement already satisfied: wcwidth in c:\users\sreenivasan\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.0.1)
# Requirement already satisfied: jupyter-core in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.0.2)
# Requirement already satisfied: tornado>=4.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\sreenivasan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.3)
# Requirement already satisfied: jinja2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.10.3)
# Requirement already satisfied: Send2Trash in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (18.1.0)
# Requirement already satisfied: prometheus-client in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.2)
# Requirement already satisfied: nbconvert in c:\users\sreenivasan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sreenivasan\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (19.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\sreenivasan\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (223)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sreenivasan\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: bleach in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.0)
# Requirement already satisfied: testpath in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: defusedxml in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sreenivasan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: webencodings in c:\users\sreenivasan\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-cp37-none-any.whl size=68730 sha256=a7a4b70e4e1e80cd2b6ed55ecbcc33d9debbbe2b4755350fdf19f17c838c95c9
#   Stored in directory: C:\Users\Sreenivasan\AppData\Local\pip\Cache\wheels\7d\ba\8d\38b672c3e40d8bd22dd60b8e6e29965b43f2b4be4d064e44d5
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3
# Collecting foliu
#   ERROR: Could not find a version that satisfies the requirement foliu (from versions: none)
# ERROR: No matching distribution found for foliu

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
iris.iplot(kind='surface', colorscale='rdylbu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-351f1d95da10> in <module>
# ----> 1 iris.iplot(kind='surface', colorscale='rdylbu')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     964                                         zmax=max(z)
#     965                                 else:
# --> 966                                         zmin=z.min()
#     967                                         zmax=z.max()
#     968
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: '<=' not supported between instances of 'float' and 'str'
