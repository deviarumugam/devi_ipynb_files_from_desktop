# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
x = [0.1*i for i in range(64)]
sin = [math.sin(i) for i in x]
cos = [math.cos(i) for i in x]
 
plt.plot(x, sin, label='sin(x)', color='blue', linewidth=2.5)
plt.plot(x, cos, label='cos(x)', color='red', linewidth=0.5)
plt.ylabel('y')
plt.xlabel('x')
plt.legend(loc='upper right')
plt.show()

# %%
pip uninstall matplotlib
python -m pip install --upgrade pip
pip install matplotlib
# Out:
#   File "<ipython-input-4-c13603e14656>", line 1
#     pip uninstall matplotlib
#                 ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

a=[]
b=[]
# y=0
# x=-50

for x in range(-50,50,1):
    y=x**2+2*x+2
    a.append(x)
    b.append(y)
    #x= x+1

fig= plt.figure()
axes=fig.add_subplot(111)
axes.plot(a,b)
plt.show()

# %%
print (math.log(2.999999999,10))
# Out:
# 0.47712125457489757

# %%
print(math.log2(10))
# Out:
# 3.321928094887362

# %%
print(math.log10(2.999999999))
# Out:
# 0.4771212545748976

# %%
print (math.erfc(6))
# Out:
# 2.1519736712498913e-17

# %%
print (math.erfc(6))
# Out:
# 1.0
